# %%
type("ali")
# Out:
# str

# %%
"ali" = "veli"
# Out:
#   File "<ipython-input-3-16316a61315a>", line 1
#     "ali" = "veli"
#                   ^
# SyntaxError: can't assign to literal

# %%
10.5
# Out:
# 10.5

# %%
type(0.0)
# Out:
# float

# %%
0.0 == 0
# Out:
# True

# %%
type(5)
# Out:
# int

# %%
bool(5)
# Out:
# True

# %%
"clarus" + "way"
# Out:
# 'clarusway'

# %%
x = 123
y = "456"
z = x + y
print("ali", z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c49b6a1176ef> in <module>()
#       1 x = 123
#       2 y = "456"
# ----> 3 z = x + y
#       4 print("ali", z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 3
type(x)
# Out:
# int

# %%
print(int("5" + "1"))
print(str("5" + "1"))
print("5" + "1")
# Out:
# 51
# 51
# 51
